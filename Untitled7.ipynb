# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyakudupudi2/Bhavyakudupudi2/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Polynomial Regression is used when the relationship between X and Y is curved, not a straight line.
#
# Simple Definition

# %%
#Y = b0 + b1X + b2X²
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Create DataFrame
df = pd.DataFrame({
    "X": [1, 2, 3, 4, 5],
    "Y": [2, 5, 10, 17, 26]
})

print(df)

# Independent Variable
X = df[["X"]]

# Dependent Variable
y = df["Y"]

# Create PolynomialFeatures object
poly = PolynomialFeatures(degree=3)

# Convert X into polynomial features
X_poly = poly.fit_transform(X)

print(X_poly)

# Train model
model = LinearRegression()

model.fit(X_poly, y)

# Prediction
print(model.predict(poly.transform([[5]])))
# Out:
#    X   Y
# 0  1   2
# 1  2   5
# 2  3  10
# 3  4  17
# 4  5  26
# [[  1.   1.   1.   1.]
#  [  1.   2.   4.   8.]
#  [  1.   3.   9.  27.]
#  [  1.   4.  16.  64.]
#  [  1.   5.  25. 125.]]
# [26.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
df = pd.DataFrame({
    "X": [1, 2, 3, 4, 5]
})
data=pd.DataFrame(df)
print(df)
obj=
# Out:
#    X
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Create DataFrame
df = pd.DataFrame({
    "X": [1, 2, 3, 4, 5],
    "Y": [2, 5, 10, 17, 26]
})

print(df)
# Independent Variable
X = df[["X"]]

# Dependent Variable
y = df["Y"]


# Create PolynomialFeatures object
poly = PolynomialFeatures(degree=2)

# Convert X into polynomial features
X_poly = poly.fit_transform(X)

print(X_poly)

# Train model
model = LinearRegression()

model.fit(X_poly, y)
# Predict values
y_pred = model.predict(X_poly)

# Plot original points
plt.scatter(df["X"], df["Y"])

# Plot polynomial curve
plt.plot(df["X"], y_pred)

plt.xlabel("X")
plt.ylabel("y")
plt.title("Polynomial Regression")

plt.show()
# Out:
#    X   Y
# 0  1   2
# 1  2   5
# 2  3  10
# 3  4  17
# 4  5  26
# [[ 1.  1.  1.]
#  [ 1.  2.  4.]
#  [ 1.  3.  9.]
#  [ 1.  4. 16.]
#  [ 1.  5. 25.]]
