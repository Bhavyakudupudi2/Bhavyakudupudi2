# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyakudupudi2/Bhavyakudupudi2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4ad804b3-2f95-4446-84a4-2c2791d7f67e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ad804b3-2f95-4446-84a4-2c2791d7f67e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("fruits1.csv")
print(df.shape)
# Out:
# (150, 4)

# %%
import pandas as pd
df=pd.read_csv("fruits1.csv")
print(df)
# Out:
#      Order Id  Apples  Orange  Banana
# 0       16723     9.0     NaN     6.0
# 1       16724    12.0    12.0     6.0
# 2       16725     9.0     NaN     NaN
# 3       16726    12.0     NaN    24.0
# 4       16727    30.0     8.0    10.0
# ..        ...     ...     ...     ...
# 145     16868    24.0    12.0     6.0
# 146     16869     8.0     8.0    12.0
# 147     16870     5.0    30.0    30.0
# 148     16871    24.0     NaN    10.0
# 149     16872     5.0    30.0    10.0
#
# [150 rows x 4 columns]

# %%
import pandas as pd
df=pd.read_csv("fruits1.csv")
print(df.Apples)
print(df["Order Id"])
# Out:
# 0       9.0
# 1      12.0
# 2       9.0
# 3      12.0
# 4      30.0
#        ...
# 145    24.0
# 146     8.0
# 147     5.0
# 148    24.0
# 149     5.0
# Name: Apples, Length: 150, dtype: float64
# 0      16723
# 1      16724
# 2      16725
# 3      16726
# 4      16727
#        ...
# 145    16868
# 146    16869
# 147    16870
# 148    16871
# 149    16872
# Name: Order Id, Length: 150, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("fruits1.csv")
s=df[['Order Id','Apples','Orange','Banana']]
print(s)
# Out:
#      Order Id  Apples  Orange  Banana
# 0       16723     9.0     NaN     6.0
# 1       16724    12.0    12.0     6.0
# 2       16725     9.0     NaN     NaN
# 3       16726    12.0     NaN    24.0
# 4       16727    30.0     8.0    10.0
# ..        ...     ...     ...     ...
# 145     16868    24.0    12.0     6.0
# 146     16869     8.0     8.0    12.0
# 147     16870     5.0    30.0    30.0
# 148     16871    24.0     NaN    10.0
# 149     16872     5.0    30.0    10.0
#
# [150 rows x 4 columns]

# %%
import pandas as pd
df=pd.read_csv("fruits1.csv")
t=df['Apples'].sum()
print(t)
# Out:
# 1808.0

# %%
import pandas as pd
df=[
    ["bhavya",20,580],
    ["surya",21,500],
    ['lalli',21,510],
    ['sri',20,500],
    ['bhavya',20,560]
]

df1=pd.DataFrame(df,columns=['name','age','marks'])

print(df1)
print()
n=df1["name"]=="bhavya"
print(df1[n])
# Out:
#      name  age  marks
# 0  bhavya   20    580
# 1   surya   21    500
# 2   lalli   21    510
# 3     sri   20    500
# 4  bhavya   20    560
#
#      name  age  marks
# 0  bhavya   20    580
# 4  bhavya   20    560

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8200ba54-90ff-4e9b-944f-943228c17caa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8200ba54-90ff-4e9b-944f-943228c17caa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[1]
print(s)
# Out:
# Order_ID              166838
# Customer_Name          Tarun
# Product          Samsung m10
# Quantity                   3
# Name: 1, dtype: object

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
print(df)
# Out:
#      Order_ID Customer_Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[-1]
print(s)
# Out:
# Order_ID                     167407
# Customer_Name                 Tarun
# Product          LG Washing Machine
# Quantity                          1
# Name: 599, dtype: object

# %%
#first column of dataframe
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[0:5,0:4]
print(s)
# Out:
#    Order_ID Customer_Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3
# 2    166839         Kedar            20in Monitor         1
# 3    166840       Lavanya               iPhone 11         3
# 4    166841          Venu      Macbook Pro Laptop         2

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[:,0:2]
print(s)
# Out:
#      Order_ID Customer_Name
# 0      166837         Veeru
# 1      166838         Tarun
# 2      166839         Kedar
# 3      166840       Lavanya
# 4      166841          Venu
# ..        ...           ...
# 595    167403        Balaji
# 596    167404       Lavanya
# 597    167405          Venu
# 598    167406        Siddhu
# 599    167407         Tarun
#
# [600 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[:,-1]
print(s)
# Out:
# 0      2
# 1      3
# 2      1
# 3      3
# 4      2
#       ..
# 595    1
# 596    1
# 597    1
# 598    2
# 599    1
# Name: Quantity, Length: 600, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[:,0:2]
print(s)
# Out:
#      Order_ID Customer_Name
# 0      166837         Veeru
# 1      166838         Tarun
# 2      166839         Kedar
# 3      166840       Lavanya
# 4      166841          Venu
# ..        ...           ...
# 595    167403        Balaji
# 596    167404       Lavanya
# 597    167405          Venu
# 598    167406        Siddhu
# 599    167407         Tarun
#
# [600 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
s=df.iloc[0:5,0:2]
print(s)
# Out:
#    Order_ID Customer_Name
# 0    166837         Veeru
# 1    166838         Tarun
# 2    166839         Kedar
# 3    166840       Lavanya
# 4    166841          Venu

# %%
#loc
import pandas as pd
df=pd.read_csv('sales1.csv')
print(df)
# Out:
#      Order_ID Customer_Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %%
#using set index
import pandas as pd
df=pd.read_csv('sales1.csv')
df.set_index("Product",inplace=True)
print(df)
# Out:
#                         Order_ID Customer_Name  Quantity
# Product
# 34in Ultrawide Monitor    166837         Veeru         2
# Samsung m10               166838         Tarun         3
# 20in Monitor              166839         Kedar         1
# iPhone 11                 166840       Lavanya         3
# Macbook Pro Laptop        166841          Venu         2
# ...                          ...           ...       ...
# Macbook Pro Laptop        167403        Balaji         1
# ThinkPad Laptop           167404       Lavanya         1
# Flatscreen TV             167405          Venu         1
# Samsung m20               167406        Siddhu         2
# LG Washing Machine        167407         Tarun         1
#
# [600 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
df.set_index("Product",inplace=True)
s=['Samsung m10','iPhone 11',]
c=['Customer_Name','Quantity']

df1=df.loc[s,c]
print(df1)
# Out:
#             Customer_Name  Quantity
# Product
# Samsung m10         Tarun         3
# Samsung m10        Harsha         1
# Samsung m10          Venu         2
# Samsung m10         Kedar         1
# Samsung m10       Sumanth         2
# ...                   ...       ...
# iPhone 11           Veeru         1
# iPhone 11           Sagar         1
# iPhone 11           Sagar         1
# iPhone 11       Madhurima         2
# iPhone 11     Mallikarjun         1
#
# [85 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
df.set_index("Product",inplace=True)
p=['Flatscreen TV','iPhone 11']
df2=df.loc[p,'Order_ID':'Quantity']
print(df2)
# Out:
#                Order_ID Customer_Name  Quantity
# Product
# Flatscreen TV    166866    Nireekshan         2
# Flatscreen TV    166911        Siddhu         1
# Flatscreen TV    166938        Partha         3
# Flatscreen TV    166961         Venki         1
# Flatscreen TV    166969       Karteek         1
# Flatscreen TV    166995       Karteek         1
# Flatscreen TV    167004       Sumanth         1
# Flatscreen TV    167052       Neelima         1
# Flatscreen TV    167053         Venki         1
# Flatscreen TV    167075       Lavanya         1
# Flatscreen TV    167094        Balaji         2
# Flatscreen TV    167100       Neelima         1
# Flatscreen TV    167102       Pradhan         1
# Flatscreen TV    167125        Harsha         3
# Flatscreen TV    167133       Sumanth         2
# Flatscreen TV    167141       Karteek         1
# Flatscreen TV    167158    Chaithanya         1
# Flatscreen TV    167242  Jaya Chandra         3
# ...

# %%
import pandas as pd
df=pd.read_csv('sales1.csv')
df.set_index("Customer_Name",inplace=True)
print(df)
# Out:
#                Order_ID                 Product  Quantity
# Customer_Name
# Veeru            166837  34in Ultrawide Monitor         2
# Tarun            166838             Samsung m10         3
# Kedar            166839            20in Monitor         1
# Lavanya          166840               iPhone 11         3
# Venu             166841      Macbook Pro Laptop         2
# ...                 ...                     ...       ...
# Balaji           167403      Macbook Pro Laptop         1
# Lavanya          167404         ThinkPad Laptop         1
# Venu             167405           Flatscreen TV         1
# Siddhu           167406             Samsung m20         2
# Tarun            167407      LG Washing Machine         1
#
# [600 rows x 3 columns]
