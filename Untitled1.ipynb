# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyakudupudi2/Bhavyakudupudi2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#reverse a string
s=input("Enter a string: ")
print(s[::-1])
# Out:
# Enter a string: bhavya
# ayvahb

# %%
s="bhavya"
print(s[::-1])
# Out:
# ayvahb

# %%
#using loop
s=[1,2,3,4,5]
print(s[::-1])
# Out:
# [5, 4, 3, 2, 1]

# %%
s=[7,8,9]
rev=[]
for n in s:
   rev=[n]+rev
print(rev)
# Out:
# [9, 8, 7]

# %%
s="bhavya"
rev=""
for n in s:
  rev=n+rev
print(rev)
# Out:
# ayvahb

# %%
s=[1,2,3,4]
rev=[]
for n in s:
  rev=[n]+rev
print(rev)
# Out:
# [4, 3, 2, 1]

# %%
#PALINROME using slicing
s=input("enter a string: ")
if s==s[::-1]:
   print("palindrome")
else:
   print("not a palinrome")
# Out:
# enter a string: maam
# palindrome

# %%
#with out using buitin functions
s=input("enter a string: ")
rev=""
for p in s:
  rev=p+rev
if s==rev:
  print("palinrome")
else:
  print("not a palinrome")
# Out:
# enter a string: bhavya
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5778/4060884601.py in <cell line: 0>()
#       1 #with out using buitin functions
# ----> 2 s=int(input("enter a string: "))
#       3 rev=""
#       4 for p in s:
#       5   rev=p+rev
#
# ValueError: invalid literal for int() with base 10: 'bhavya'

# %%
#armstrong number
num = int(input("Enter a number: "))

temp = num
sum = 0
#digits=len(str(num))
digits=len("153")
while temp > 0:
    digit = temp % 10
    sum = sum + digit ** digits
    temp = temp // 10

if sum == num:
    print("Armstrong Number")
else:
    print("Not Armstrong Number")
# Out:
# Enter a number: 153
# Armstrong Number

# %%
num=int(input("Enter a number : "))
temp=num
sum=0
digits=len(str(num))

while temp > 0:
  digit = temp % 10
  sum = sum + digit ** digits
  temp = temp // 10
if sum == num:
  print("Armstrong number")
else:
  print("Not an Armstrong number")
# Out:
# Enter a number : 153
# Armstrong number

# %%
num=int(input("Enetr a number: "))
if (num%2==0):
  print("Even")
else:
  print("odd")
# Out:
# Enetr a number: 5
# odd

# %%
num=int(input("Enter a number"))
count=0
for i in range(1,num+1):
   if num% i==0:
    count=count+1
if count==2:
   print("prime number")
else:
  print("not a prime number")
# Out:
# Enter a number4
# not a prime number

# %%
'''7 → No break → else runs → Prime
8 → break occurs → else does not run → Not Prime'''
num=int(input("Enter a number: "))
if num > 1:
  for i in range(2,num):
    if num % i == 0:
       print("not a prime number")
       break
  else:
      print("prime number")
else:
  print("not a prime number")
# Out:
# Enter a number: 6
# not a prime number

# %%
n=input("enter a string: ")
print(s[::-1])
# Out:
# enter a string: bhavya
# ayvahb

# %%
n=input("enter a string:")
rev=""
for r in n:
  rev=r+rev
print(rev)
# Out:
# enter a string:bhavya
# ayvahb

# %%
#palindrom
s=input("Enter a string: ")
if s==s[::-1]:
  print("palinrome")
else:
  print("not a palindrome")
# Out:
# Enter a string: mam
# palinrome

# %%
s=input("enter a number: ")
if s==s[::-1]:
  print("palinrome")
else:
  print("not a palindrome")
# Out:
# enter a number: 535
# palinrome

# %%
s=input("enter a string: ")
rev=""
for p in s:
  rev=p+rev
if s == rev:
    print("palindrome")
else:
  print("not a palindrome")
# Out:
# enter a string: madam
# palindrome

# %%
#armstrong
num=int(input("Enter a number"))
temp=num
sum=0
digits=len(str(num))
while temp > 0:
  digit=temp % 10
  sum=sum+digit ** digits
  temp=temp // 10
if sum==num:
  print("Armstrong")
else:
  print("not a armstrong number")
# Out:
# Enter a number153
# Armstrong

# %%
#prime number
num=int(input("enter a number: "))
if num>1:
   for i in range(2,num):
    if num%i==0:
       print("not a prime")
       break
   else:
        print("prime num")
else:
  print("not a prime")
# Out:
# enter a number: 5
# prime num
